# %% [markdown]
# # TransMIL Result Visualization
# This notebook demonstrates how to load trained models and visualize anomaly scores.

# %%
import sys
sys.path.append('../src')
import torch
import numpy as np
import matplotlib.pyplot as plt
from utils.visualization import plot_temporal_scores
